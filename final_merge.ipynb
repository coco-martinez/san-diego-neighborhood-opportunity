# %% [markdown]
# <a href="https://colab.research.google.com/github/coco-martinez/san-diego-neighborhood-opportunity/blob/main/final_merge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %%
# !git clone https://github.com/coco-martinez/san-diego-neighborhood-opportunity.git
# Out:
# Cloning into 'san-diego-neighborhood-opportunity'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 86 (delta 24), reused 78 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (86/86), 6.73 MiB | 6.53 MiB/s, done.
# Resolving deltas: 100% (24/24), done.

# %%
project_path = Path('/content/san-diego-neighborhood-opportunity')
processed_path = project_path / 'data/processed'

processed_path.exists()
# Out:
# True

# %%
list(processed_path.glob('*.csv'))
# Out:
# [PosixPath('/content/san-diego-neighborhood-opportunity/data/processed/crime_safety_by_tract.csv'),
#  PosixPath('/content/san-diego-neighborhood-opportunity/data/processed/school_features_by_tract.csv'),
#  PosixPath('/content/san-diego-neighborhood-opportunity/data/processed/environmental_burden_by_tract.csv'),
#  PosixPath('/content/san-diego-neighborhood-opportunity/data/processed/walkability_by_tract.csv'),
#  PosixPath('/content/san-diego-neighborhood-opportunity/data/processed/acs_tracts_selected_2024.csv'),
#  PosixPath('/content/san-diego-neighborhood-opportunity/data/processed/transit_access_by_tract.csv')]

# %%
# loading each cleaned tract-level dataset
acs = pd.read_csv(processed_path / 'acs_tracts_selected_2024.csv')
crime = pd.read_csv(processed_path / 'crime_safety_by_tract.csv')
walkability = pd.read_csv(processed_path / 'walkability_by_tract.csv')
transit = pd.read_csv(processed_path / 'transit_access_by_tract.csv')
environment = pd.read_csv(processed_path / 'environmental_burden_by_tract.csv')
schools = pd.read_csv(processed_path / 'school_features_by_tract.csv')

datasets = {
    'acs': acs,
    'crime': crime,
    'walkability': walkability,
    'transit': transit,
    'environment': environment,
    'schools': schools}
